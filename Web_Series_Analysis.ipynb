# %% [markdown]
# #Web Series Analysis

# %% [markdown]
# #Task 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Task 1: Trend of Web Series Released Per Year (Line Chart)
plt.figure(figsize=(10, 6))
release_trend = df['Year'].value_counts().sort_index()
sns.lineplot(x=release_trend.index, y=release_trend.values, marker='o')
plt.title("Trend of Web Series Released Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Web Series")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 2

# %%
# Task 2: Distribution of IMDB Ratings Across Streaming Platforms (Box Plot)
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Platform', y='IMDB Rating', palette='Set2')
plt.title("Distribution of IMDB Ratings Across Streaming Platforms")
plt.xlabel("Streaming Platform")
plt.ylabel("IMDB Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Dataset (manually entered as it was extracted from the PDF)
data = {
    "Series ID": [201, 202, 203, 204, 205, 206, 207, 208, 209, 210,
                  211, 212, 213, 214, 215, 216, 217, 218, 219, 220,
                  221, 222, 223, 224, 225, 226, 227, 228, 229, 230,
                  231, 232, 233, 234, 235, 236, 237, 238, 239, 240,
                  241, 242, 243, 244, 245, 246, 247, 248, 249, 250],
    "Title": ["Sacred Games", "Mirzapur", "The Family Man", "Paatal Lok", "Asur", "Delhi Crime", "Breathe", "Special OPS", "Made in Heaven", "Kota Factory",
              "Panchayat", "Criminal Justice", "Scam 1992", "Hostel Daze", "Little Things", "Aarya", "Bard of Blood", "Rangbaaz", "Inside Edge", "TVF Pitchers",
              "Jamtara", "Lakhon Mein Ek", "Betaal", "Tandav", "Ray", "Mumbai Diaries", "Aranyak", "Masaba Masaba", "She", "Bandish Bandits",
              "Typewriter", "Leila", "Ghoul", "Four More Shots Please", "Bose: Dead/Alive", "Selection Day", "The Test Case", "Code M", "JL50", "Illegal",
              "Avrodh", "Cartel", "Undekhi", "Sunflower", "Jeet Ki Zid", "Kaun Banegi Shikharwati", "Candy", "Mai", "Rocket Boys", "Human"],
    "IMDB Rating": [8.8, 6.5, 6.8, 7.9, 7.1, 6.9, 6.5, 6.7, 8.6, 8.5,
                    7.1, 9.3, 7.0, 8.4, 6.9, 8.3, 8.2, 7.8, 6.6, 6.6,
                    7.1, 6.7, 7.9, 9.1, 9.1, 9.3, 6.5, 6.9, 9.1, 6.9,
                    7.1, 9.3, 8.3, 7.3, 6.7, 7.6, 8.0, 7.4, 8.7, 8.0,
                    6.7, 9.3, 7.4, 9.3, 6.9, 6.6, 8.5, 6.6, 8.6, 6.9]
}

df = pd.DataFrame(data)

# Sort and select top 5
top_5 = df.sort_values(by="IMDB Rating", ascending=False).head(5)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x="IMDB Rating", y="Title", data=top_5, palette="viridis")
plt.title("Top 5 Highest Rated Web Series")
plt.xlabel("IMDB Rating")
plt.ylabel("Web Series Title")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data with Title and Genre
genre_data = {
    "Title": ["Sacred Games", "Mirzapur", "The Family Man", "Paatal Lok", "Asur", "Delhi Crime", "Breathe", "Special OPS", "Made in Heaven", "Kota Factory",
              "Panchayat", "Criminal Justice", "Scam 1992", "Hostel Daze", "Little Things", "Aarya", "Bard of Blood", "Rangbaaz", "Inside Edge", "TVF Pitchers",
              "Jamtara", "Lakhon Mein Ek", "Betaal", "Tandav", "Ray", "Mumbai Diaries", "Aranyak", "Masaba Masaba", "She", "Bandish Bandits",
              "Typewriter", "Leila", "Ghoul", "Four More Shots Please", "Bose: Dead/Alive", "Selection Day", "The Test Case", "Code M", "JL50", "Illegal",
              "Avrodh", "Cartel", "Undekhi", "Sunflower", "Jeet Ki Zid", "Kaun Banegi Shikharwati", "Candy", "Mai", "Rocket Boys", "Human"],
    "Genre": ["Crime", "Drama", "Sci-Fi", "Drama", "Sci-Fi", "Sci-Fi", "Crime", "Crime", "Thriller", "Mystery",
              "Drama", "Mystery", "Drama", "Sci-Fi", "Mystery", "Thriller", "Mystery", "Sci-Fi", "Drama", "Mystery",
              "Sci-Fi", "Sci-Fi", "Mystery", "Mystery", "Comedy", "Comedy", "Sci-Fi", "Mystery", "Sci-Fi", "Sci-Fi",
              "Sci-Fi", "Crime", "Sci-Fi", "Thriller", "Crime", "Sci-Fi", "Thriller", "Mystery", "Comedy", "Thriller",
              "Sci-Fi", "Sci-Fi", "Comedy", "Mystery", "Comedy", "Comedy", "Thriller", "Mystery", "Mystery", "Sci-Fi"]
}

# Create DataFrame
genre_df = pd.DataFrame(genre_data)

# Count occurrences of each genre
genre_counts = genre_df["Genre"].value_counts().reset_index()
genre_counts.columns = ["Genre", "Count"]

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x="Genre", y="Count", data=genre_counts, palette="Set2")
plt.title("Genre Distribution of Web Series")
plt.xlabel("Genre")
plt.ylabel("Number of Web Series")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

data = """
Series ID,Genre,Title,Platform,Seasons,Episodes,IMDB Rating,Year
201,Crime,Sacred Games,Zee5,2,8,8.8,2021
202,Drama,Mirzapur,Zee5,1,12,6.5,2022
203,Sci-Fi,The Family Man,Zee5,1,13,6.8,2022
204,Drama,Paatal Lok,Voot,1,13,7.9,2022
205,Sci-Fi,Asur,SonyLIV,2,14,7.1,2019
206,SciFi-,Delhi Crime,Voot,3,14,6.9,2019
207,Crime,Breathe,Zee5,1,8,6.5,2019
208,Crime,Special Ops,Amazon P,3,13,6.7,2021
209,Thriller,Made in Heaven,Amazon P,2,10,8.6,2017
210,Mystery,Kota Factory,Voot,3,13,8.5,2019
211,Drama,Panchayat,Amazon P,3,11,7.1,2021
212,Mystery,Criminal Justice,Netflix,1,6,9.3,2021
213,Drama,Scam 1992,Voot,3,12,7.0,2017
214,Sci-Fi,Hostel Daze,Hotstar,1,10,8.4,2022
215,Mystery,Little Things,SonyLIV,1,7,6.9,2021
216,Thriller,Aarya,Zee5,3,14,8.3,2022
217,Mystery,Bard of Blood,Zee5,2,13,8.2,2023
218,Sci-Fi,Rangbaaz,Netflix,1,14,7.8,2021
219,Drama,Inside Edge,Hotstar,1,13,6.6,2021
220,Mystery,TVF Pitchers,SonyLIV,3,14,6.6,2021
221,Sci-Fi,Jamtara,Zee5,1,10,7.1,2018
222,Sci-Fi, Lakhon Mein Ek,Voot,3,13,6.7,2021
223,Mystery,Betaal,Hotstar,3,10,7.9,2022
224,Mystery,Tandav,Hotstar,2,10,9.1,2022
225,Comedy,Comedy Ray,Netflix,1,11,9.1,2023
226,Comedy,Mumbai,Amazon P,1,14,9.3,2022
227,Sci-Fi,Aranyak,SonyLIV,1,7,6.5,2017
228,Mystery,Masaba Masaba,Netflix,3,6,6.9,2022
229,Sci-Fi,She,Amazon P,1,11,9.1,2020
230,Sci-Fi,Bandish Bandits,Voot,2,11,6.9,2019
231,Sci-Fi,Typewriter,Netflix,1,10,7.1,2021
232,Crime,Leila,Hotstar,3,11,9.3,2019
233,Sci-Fi,Ghoul,SonyLIV,2,9,8.3,2017
234,Thriller,Four More Shots Please!,Voot,1,6,7.3,2019
235,Crime,Bose: Dead/Alive,Amazon P,3,9,6.7,2020
236,Sci-Fi,Selection Day,Zee5,2,13,7.6,2018
237,Thriller,The Test Case,Zee5,1,8,8.0,2019
238,Mystery,Code M,Hotstar,2,11,7.4,2017
239,Comedy,JL50,Zee5,3,14,8.7,2023
240,Thriller,Illegal,Amazon P,2,6,8.0,2023
241,Sci-Fi,Avrodh,SonyLIV,3,13,6.7,2018
242,Sci-Fi,Cartel,Hotstar,2,13,9.3,2022
243,Comedy,Undekhi,SonyLIV,2,12,7.4,2022
244,Mystery,Sunflower,SonyLIV,1,8,9.3,2023
245,Comedy,Jeet Ki Zid,Hotstar,3,6,6.9,2022
246,Comedy,Kaun Banega Shikharwati,SonyLIV,3,14,6.6,2023
247,Thriller,Candy,Voot,3,8,8.5,2020
248,Mystery,Mai,Voot,3,6,6.6,2018
249,Mystery,Rocket Boys,SonyLIV,3,8,8.6,2019
250,Sci-Fi,Human,Netflix,1,10,6.9,2022
"""

df = pd.read_csv(io.StringIO(data))

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Episodes'], df['IMDB Rating'], alpha=0.7)
plt.title('Relationship Between Number of Episodes and IMDB Rating')
plt.xlabel('Number of Episodes')
plt.ylabel('IMDB Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

data = """
Series ID,Genre,Title,Platform,Seasons,Episodes,IMDB Rating,Year
201,Crime,Sacred Games,Zee5,2,8,8.8,2021
202,Drama,Mirzapur,Zee5,1,12,6.5,2022
203,Sci-Fi,The Family Man,Zee5,1,13,6.8,2022
204,Drama,Paatal Lok,Voot,1,13,7.9,2022
205,Sci-Fi,Asur,SonyLIV,2,14,7.1,2019
206,SciFi-,Delhi Crime,Voot,3,14,6.9,2019
207,Crime,Breathe,Zee5,1,8,6.5,2019
208,Crime,Special Ops,Amazon P,3,13,6.7,2021
209,Thriller,Made in Heaven,Amazon P,2,10,8.6,2017
210,Mystery,Kota Factory,Voot,3,13,8.5,2019
211,Drama,Panchayat,Amazon P,3,11,7.1,2021
212,Mystery,Criminal Justice,Netflix,1,6,9.3,2021
213,Drama,Scam 1992,Voot,3,12,7.0,2017
214,Sci-Fi,Hostel Daze,Hotstar,1,10,8.4,2022
215,Mystery,Little Things,SonyLIV,1,7,6.9,2021
216,Thriller,Aarya,Zee5,3,14,8.3,2022
217,Mystery,Bard of Blood,Zee5,2,13,8.2,2023
218,Sci-Fi,Rangbaaz,Netflix,1,14,7.8,2021
219,Drama,Inside Edge,Hotstar,1,13,6.6,2021
220,Mystery,TVF Pitchers,SonyLIV,3,14,6.6,2021
221,Sci-Fi,Jamtara,Zee5,1,10,7.1,2018
222,Sci-Fi, Lakhon Mein Ek,Voot,3,13,6.7,2021
223,Mystery,Betaal,Hotstar,3,10,7.9,2022
224,Mystery,Tandav,Hotstar,2,10,9.1,2022
225,Comedy,Comedy Ray,Netflix,1,11,9.1,2023
226,Comedy,Mumbai,Amazon P,1,14,9.3,2022
227,Sci-Fi,Aranyak,SonyLIV,1,7,6.5,2017
228,Mystery,Masaba Masaba,Netflix,3,6,6.9,2022
229,Sci-Fi,She,Amazon P,1,11,9.1,2020
230,Sci-Fi,Bandish Bandits,Voot,2,11,6.9,2019
231,Sci-Fi,Typewriter,Netflix,1,10,7.1,2021
232,Crime,Leila,Hotstar,3,11,9.3,2019
233,Sci-Fi,Ghoul,SonyLIV,2,9,8.3,2017
234,Thriller,Four More Shots Please!,Voot,1,6,7.3,2019
235,Crime,Bose: Dead/Alive,Amazon P,3,9,6.7,2020
236,Sci-Fi,Selection Day,Zee5,2,13,7.6,2018
237,Thriller,The Test Case,Zee5,1,8,8.0,2019
238,Mystery,Code M,Hotstar,2,11,7.4,2017
239,Comedy,JL50,Zee5,3,14,8.7,2023
240,Thriller,Illegal,Amazon P,2,6,8.0,2023
241,Sci-Fi,Avrodh,SonyLIV,3,13,6.7,2018
242,Sci-Fi,Cartel,Hotstar,2,13,9.3,2022
243,Comedy,Undekhi,SonyLIV,2,12,7.4,2022
244,Mystery,Sunflower,SonyLIV,1,8,9.3,2023
245,Comedy,Jeet Ki Zid,Hotstar,3,6,6.9,2022
246,Comedy,Kaun Banega Shikharwati,SonyLIV,3,14,6.6,2023
247,Thriller,Candy,Voot,3,8,8.5,2020
248,Mystery,Mai,Voot,3,6,6.6,2018
249,Mystery,Rocket Boys,SonyLIV,3,8,8.6,2019
250,Sci-Fi,Human,Netflix,1,10,6.9,2022
"""

df = pd.read_csv(io.StringIO(data))

# Group data by 'Platform' and 'Genre', and calculate the mean IMDB Rating
grouped_data = df.groupby(['Platform', 'Genre'])['IMDB Rating'].mean().reset_index()

# Create the heatmap
plt.figure(figsize=(12, 8))
heatmap_data = grouped_data.pivot_table(index='Genre', columns='Platform', values='IMDB Rating')
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".1f")  # fmt ensures one decimal place
plt.title('Platform-Wise Average IMDB Rating by Genre')
plt.xlabel('Platform')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

data = """
Series ID,Genre,Title,Platform,Seasons,Episodes,IMDB Rating,Year
201,Crime,Sacred Games,Zee5,2,8,8.8,2021
202,Drama,Mirzapur,Zee5,1,12,6.5,2022
203,Sci-Fi,The Family Man,Zee5,1,13,6.8,2022
204,Drama,Paatal Lok,Voot,1,13,7.9,2022
205,Sci-Fi,Asur,SonyLIV,2,14,7.1,2019
206,SciFi-,Delhi Crime,Voot,3,14,6.9,2019
207,Crime,Breathe,Zee5,1,8,6.5,2019
208,Crime,Special Ops,Amazon P,3,13,6.7,2021
209,Thriller,Made in Heaven,Amazon P,2,10,8.6,2017
210,Mystery,Kota Factory,Voot,3,13,8.5,2019
211,Drama,Panchayat,Amazon P,3,11,7.1,2021
212,Mystery,Criminal Justice,Netflix,1,6,9.3,2021
213,Drama,Scam 1992,Voot,3,12,7.0,2017
214,Sci-Fi,Hostel Daze,Hotstar,1,10,8.4,2022
215,Mystery,Little Things,SonyLIV,1,7,6.9,2021
216,Thriller,Aarya,Zee5,3,14,8.3,2022
217,Mystery,Bard of Blood,Zee5,2,13,8.2,2023
218,Sci-Fi,Rangbaaz,Netflix,1,14,7.8,2021
219,Drama,Inside Edge,Hotstar,1,13,6.6,2021
220,Mystery,TVF Pitchers,SonyLIV,3,14,6.6,2021
221,Sci-Fi,Jamtara,Zee5,1,10,7.1,2018
222,Sci-Fi, Lakhon Mein Ek,Voot,3,13,6.7,2021
223,Mystery,Betaal,Hotstar,3,10,7.9,2022
224,Mystery,Tandav,Hotstar,2,10,9.1,2022
225,Comedy,Comedy Ray,Netflix,1,11,9.1,2023
226,Comedy,Mumbai,Amazon P,1,14,9.3,2022
227,Sci-Fi,Aranyak,SonyLIV,1,7,6.5,2017
228,Mystery,Masaba Masaba,Netflix,3,6,6.9,2022
229,Sci-Fi,She,Amazon P,1,11,9.1,2020
230,Sci-Fi,Bandish Bandits,Voot,2,11,6.9,2019
231,Sci-Fi,Typewriter,Netflix,1,10,7.1,2021
232,Crime,Leila,Hotstar,3,11,9.3,2019
233,Sci-Fi,Ghoul,SonyLIV,2,9,8.3,2017
234,Thriller,Four More Shots Please!,Voot,1,6,7.3,2019
235,Crime,Bose: Dead/Alive,Amazon P,3,9,6.7,2020
236,Sci-Fi,Selection Day,Zee5,2,13,7.6,2018
237,Thriller,The Test Case,Zee5,1,8,8.0,2019
238,Mystery,Code M,Hotstar,2,11,7.4,2017
239,Comedy,JL50,Zee5,3,14,8.7,2023
240,Thriller,Illegal,Amazon P,2,6,8.0,2023
241,Sci-Fi,Avrodh,SonyLIV,3,13,6.7,2018
242,Sci-Fi,Cartel,Hotstar,2,13,9.3,2022
243,Comedy,Undekhi,SonyLIV,2,12,7.4,2022
244,Mystery,Sunflower,SonyLIV,1,8,9.3,2023
245,Comedy,Jeet Ki Zid,Hotstar,3,6,6.9,2022
246,Comedy,Kaun Banega Shikharwati,SonyLIV,3,14,6.6,2023
247,Thriller,Candy,Voot,3,8,8.5,2020
248,Mystery,Mai,Voot,3,6,6.6,2018
249,Mystery,Rocket Boys,SonyLIV,3,8,8.6,2019
250,Sci-Fi,Human,Netflix,1,10,6.9,2022
"""

df = pd.read_csv(io.StringIO(data))

# Calculate Episodes per Season
df['Episodes_Per_Season'] = df['Episodes'] / df['Seasons']

# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(df['Title'], df['Episodes_Per_Season'])
plt.title('Average Number of Episodes Per Season')
plt.xlabel('Web Series Title')
plt.ylabel('Episodes Per Season')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

data = """
Series ID,Genre,Title,Platform,Seasons,Episodes,IMDB Rating,Year
201,Crime,Sacred Games,Zee5,2,8,8.8,2021
202,Drama,Mirzapur,Zee5,1,12,6.5,2022
203,Sci-Fi,The Family Man,Zee5,1,13,6.8,2022
204,Drama,Paatal Lok,Voot,1,13,7.9,2022
205,Sci-Fi,Asur,SonyLIV,2,14,7.1,2019
206,SciFi-,Delhi Crime,Voot,3,14,6.9,2019
207,Crime,Breathe,Zee5,1,8,6.5,2019
208,Crime,Special Ops,Amazon P,3,13,6.7,2021
209,Thriller,Made in Heaven,Amazon P,2,10,8.6,2017
210,Mystery,Kota Factory,Voot,3,13,8.5,2019
211,Drama,Panchayat,Amazon P,3,11,7.1,2021
212,Mystery,Criminal Justice,Netflix,1,6,9.3,2021
213,Drama,Scam 1992,Voot,3,12,7.0,2017
214,Sci-Fi,Hostel Daze,Hotstar,1,10,8.4,2022
215,Mystery,Little Things,SonyLIV,1,7,6.9,2021
216,Thriller,Aarya,Zee5,3,14,8.3,2022
217,Mystery,Bard of Blood,Zee5,2,13,8.2,2023
218,Sci-Fi,Rangbaaz,Netflix,1,14,7.8,2021
219,Drama,Inside Edge,Hotstar,1,13,6.6,2021
220,Mystery,TVF Pitchers,SonyLIV,3,14,6.6,2021
221,Sci-Fi,Jamtara,Zee5,1,10,7.1,2018
222,Sci-Fi, Lakhon Mein Ek,Voot,3,13,6.7,2021
223,Mystery,Betaal,Hotstar,3,10,7.9,2022
224,Mystery,Tandav,Hotstar,2,10,9.1,2022
225,Comedy,Comedy Ray,Netflix,1,11,9.1,2023
226,Comedy,Mumbai,Amazon P,1,14,9.3,2022
227,Sci-Fi,Aranyak,SonyLIV,1,7,6.5,2017
228,Mystery,Masaba Masaba,Netflix,3,6,6.9,2022
229,Sci-Fi,She,Amazon P,1,11,9.1,2020
230,Sci-Fi,Bandish Bandits,Voot,2,11,6.9,2019
231,Sci-Fi,Typewriter,Netflix,1,10,7.1,2021
232,Crime,Leila,Hotstar,3,11,9.3,2019
233,Sci-Fi,Ghoul,SonyLIV,2,9,8.3,2017
234,Thriller,Four More Shots Please!,Voot,1,6,7.3,2019
235,Crime,Bose: Dead/Alive,Amazon P,3,9,6.7,2020
236,Sci-Fi,Selection Day,Zee5,2,13,7.6,2018
237,Thriller,The Test Case,Zee5,1,8,8.0,2019
238,Mystery,Code M,Hotstar,2,11,7.4,2017
239,Comedy,JL50,Zee5,3,14,8.7,2023
240,Thriller,Illegal,Amazon P,2,6,8.0,2023
241,Sci-Fi,Avrodh,SonyLIV,3,13,6.7,2018
242,Sci-Fi,Cartel,Hotstar,2,13,9.3,2022
243,Comedy,Undekhi,SonyLIV,2,12,7.4,2022
244,Mystery,Sunflower,SonyLIV,1,8,9.3,2023
245,Comedy,Jeet Ki Zid,Hotstar,3,6,6.9,2022
246,Comedy,Kaun Banega Shikharwati,SonyLIV,3,14,6.6,2023
247,Thriller,Candy,Voot,3,8,8.5,2020
248,Mystery,Mai,Voot,3,6,6.6,2018
249,Mystery,Rocket Boys,SonyLIV,3,8,8.6,2019
250,Sci-Fi,Human,Netflix,1,10,6.9,2022
"""

df = pd.read_csv(io.StringIO(data))

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Seasons', y='IMDB Rating', hue='Platform')
plt.title('IMDB Rating vs. Number of Seasons (Grouped by Platform)')
plt.xlabel('Number of Seasons')
plt.ylabel('IMDB Rating')
plt.grid(True)
plt.legend(title='Platform') # Add legend title
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task  9

# %%
import pandas as pd
import io

data = """
Series ID,Genre,Title,Platform,Seasons,Episodes,IMDB Rating,Year
201,Crime,Sacred Games,Zee5,2,8,8.8,2021
202,Drama,Mirzapur,Zee5,1,12,6.5,2022
203,Sci-Fi,The Family Man,Zee5,1,13,6.8,2022
204,Drama,Paatal Lok,Voot,1,13,7.9,2022
205,Sci-Fi,Asur,SonyLIV,2,14,7.1,2019
206,SciFi-,Delhi Crime,Voot,3,14,6.9,2019
207,Crime,Breathe,Zee5,1,8,6.5,2019
208,Crime,Special Ops,Amazon P,3,13,6.7,2021
209,Thriller,Made in Heaven,Amazon P,2,10,8.6,2017
210,Mystery,Kota Factory,Voot,3,13,8.5,2019
211,Drama,Panchayat,Amazon P,3,11,7.1,2021
212,Mystery,Criminal Justice,Netflix,1,6,9.3,2021
213,Drama,Scam 1992,Voot,3,12,7.0,2017
214,Sci-Fi,Hostel Daze,Hotstar,1,10,8.4,2022
215,Mystery,Little Things,SonyLIV,1,7,6.9,2021
216,Thriller,Aarya,Zee5,3,14,8.3,2022
217,Mystery,Bard of Blood,Zee5,2,13,8.2,2023
218,Sci-Fi,Rangbaaz,Netflix,1,14,7.8,2021
219,Drama,Inside Edge,Hotstar,1,13,6.6,2021
220,Mystery,TVF Pitchers,SonyLIV,3,14,6.6,2021
221,Sci-Fi,Jamtara,Zee5,1,10,7.1,2018
222,Sci-Fi, Lakhon Mein Ek,Voot,3,13,6.7,2021
223,Mystery,Betaal,Hotstar,3,10,7.9,2022
224,Mystery,Tandav,Hotstar,2,10,9.1,2022
225,Comedy,Comedy Ray,Netflix,1,11,9.1,2023
226,Comedy,Mumbai,Amazon P,1,14,9.3,2022
227,Sci-Fi,Aranyak,SonyLIV,1,7,6.5,2017
228,Mystery,Masaba Masaba,Netflix,3,6,6.9,2022
229,Sci-Fi,She,Amazon P,1,11,9.1,2020
230,Sci-Fi,Bandish Bandits,Voot,2,11,6.9,2019
231,Sci-Fi,Typewriter,Netflix,1,10,7.1,2021
232,Crime,Leila,Hotstar,3,11,9.3,2019
233,Sci-Fi,Ghoul,SonyLIV,2,9,8.3,2017
234,Thriller,Four More Shots Please!,Voot,1,6,7.3,2019
235,Crime,Bose: Dead/Alive,Amazon P,3,9,6.7,2020
236,Sci-Fi,Selection Day,Zee5,2,13,7.6,2018
237,Thriller,The Test Case,Zee5,1,8,8.0,2019
238,Mystery,Code M,Hotstar,2,11,7.4,2017
239,Comedy,JL50,Zee5,3,14,8.7,2023
240,Thriller,Illegal,Amazon P,2,6,8.0,2023
241,Sci-Fi,Avrodh,SonyLIV,3,13,6.7,2018
242,Sci-Fi,Cartel,Hotstar,2,13,9.3,2022
243,Comedy,Undekhi,SonyLIV,2,12,7.4,2022
244,Mystery,Sunflower,SonyLIV,1,8,9.3,2023
245,Comedy,Jeet Ki Zid,Hotstar,3,6,6.9,2022
246,Comedy,Kaun Banega Shikharwati,SonyLIV,3,14,6.6,2023
247,Thriller,Candy,Voot,3,8,8.5,2020
248,Mystery,Mai,Voot,3,6,6.6,2018
249,Mystery,Rocket Boys,SonyLIV,3,8,8.6,2019
250,Sci-Fi,Human,Netflix,1,10,6.9,2022
"""

df = pd.read_csv(io.StringIO(data))

# Calculate the variance of IMDB Ratings for each genre
genre_variance = df.groupby('Genre')['IMDB Rating'].var().reset_index()

# Sort by variance in ascending order (most consistent to least)
genre_variance_sorted = genre_variance.sort_values(by='IMDB Rating')

# Display the results
print("Genre Variance in IMDB Ratings:")
print(genre_variance_sorted.to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# Genre Variance in IMDB Ratings:
# | Genre    | IMDB Rating   |
# |:---------|:--------------|
# | Thriller | 0.221667      |
# | Drama    | 0.307         |
# | Sci-Fi   | 0.808381      |
# | Mystery  | 1.08265       |
# | Comedy   | 1.384         |
# | Crime    | 1.79          |
# | SciFi-   | nan           |

# %% [markdown]
# #Task 10

# %%
import pandas as pd
import io

data = """
Series ID,Genre,Title,Platform,Seasons,Episodes,IMDB Rating,Year
201,Crime,Sacred Games,Zee5,2,8,8.8,2021
202,Drama,Mirzapur,Zee5,1,12,6.5,2022
203,Sci-Fi,The Family Man,Zee5,1,13,6.8,2022
204,Drama,Paatal Lok,Voot,1,13,7.9,2022
205,Sci-Fi,Asur,SonyLIV,2,14,7.1,2019
206,SciFi-,Delhi Crime,Voot,3,14,6.9,2019
207,Crime,Breathe,Zee5,1,8,6.5,2019
208,Crime,Special Ops,Amazon P,3,13,6.7,2021
209,Thriller,Made in Heaven,Amazon P,2,10,8.6,2017
210,Mystery,Kota Factory,Voot,3,13,8.5,2019
211,Drama,Panchayat,Amazon P,3,11,7.1,2021
212,Mystery,Criminal Justice,Netflix,1,6,9.3,2021
213,Drama,Scam 1992,Voot,3,12,7.0,2017
214,Sci-Fi,Hostel Daze,Hotstar,1,10,8.4,2022
215,Mystery,Little Things,SonyLIV,1,7,6.9,2021
216,Thriller,Aarya,Zee5,3,14,8.3,2022
217,Mystery,Bard of Blood,Zee5,2,13,8.2,2023
218,Sci-Fi,Rangbaaz,Netflix,1,14,7.8,2021
219,Drama,Inside Edge,Hotstar,1,13,6.6,2021
220,Mystery,TVF Pitchers,SonyLIV,3,14,6.6,2021
221,Sci-Fi,Jamtara,Zee5,1,10,7.1,2018
222,Sci-Fi, Lakhon Mein Ek,Voot,3,13,6.7,2021
223,Mystery,Betaal,Hotstar,3,10,7.9,2022
224,Mystery,Tandav,Hotstar,2,10,9.1,2022
225,Comedy,Comedy Ray,Netflix,1,11,9.1,2023
226,Comedy,Mumbai,Amazon P,1,14,9.3,2022
227,Sci-Fi,Aranyak,SonyLIV,1,7,6.5,2017
228,Mystery,Masaba Masaba,Netflix,3,6,6.9,2022
229,Sci-Fi,She,Amazon P,1,11,9.1,2020
230,Sci-Fi,Bandish Bandits,Voot,2,11,6.9,2019
231,Sci-Fi,Typewriter,Netflix,1,10,7.1,2021
232,Crime,Leila,Hotstar,3,11,9.3,2019
233,Sci-Fi,Ghoul,SonyLIV,2,9,8.3,2017
234,Thriller,Four More Shots Please!,Voot,1,6,7.3,2019
235,Crime,Bose: Dead/Alive,Amazon P,3,9,6.7,2020
236,Sci-Fi,Selection Day,Zee5,2,13,7.6,2018
237,Thriller,The Test Case,Zee5,1,8,8.0,2019
238,Mystery,Code M,Hotstar,2,11,7.4,2017
239,Comedy,JL50,Zee5,3,14,8.7,2023
240,Thriller,Illegal,Amazon P,2,6,8.0,2023
241,Sci-Fi,Avrodh,SonyLIV,3,13,6.7,2018
242,Sci-Fi,Cartel,Hotstar,2,13,9.3,2022
243,Comedy,Undekhi,SonyLIV,2,12,7.4,2022
244,Mystery,Sunflower,SonyLIV,1,8,9.3,2023
245,Comedy,Jeet Ki Zid,Hotstar,3,6,6.9,2022
246,Comedy,Kaun Banega Shikharwati,SonyLIV,3,14,6.6,2023
247,Thriller,Candy,Voot,3,8,8.5,2020
248,Mystery,Mai,Voot,3,6,6.6,2018
249,Mystery,Rocket Boys,SonyLIV,3,8,8.6,2019
250,Sci-Fi,Human,Netflix,1,10,6.9,2022
"""

df = pd.read_csv(io.StringIO(data))

# Calculate the average IMDB rating for each genre
genre_avg_ratings = df.groupby('Genre')['IMDB Rating'].mean().reset_index()

# Create a dictionary to store web series with above-average ratings for each genre
above_avg_series = {}

# Iterate through each genre
for genre in df['Genre'].unique():
    # Get the average rating for the current genre
    avg_rating = genre_avg_ratings[genre_avg_ratings['Genre'] == genre]['IMDB Rating'].values[0]

    # Filter web series with ratings above the genre's average
    above_avg = df[(df['Genre'] == genre) & (df['IMDB Rating'] > avg_rating)]

    # Store the titles in the dictionary
    above_avg_series[genre] = above_avg['Title'].tolist()

# Print the results
for genre, series_list in above_avg_series.items():
    print(f"Genre: {genre}")
    if series_list:
        print(f"  Web series with above-average ratings: {', '.join(series_list)}")
    else:
        print("  No web series with above-average ratings in this genre.")
    print("-" * 40)
# Out:
# Genre: Crime
#   Web series with above-average ratings: Sacred Games, Leila
# ----------------------------------------
# Genre: Drama
#   Web series with above-average ratings: Paatal Lok, Panchayat
# ----------------------------------------
# Genre: Sci-Fi
#   Web series with above-average ratings: Hostel Daze, Rangbaaz, She, Ghoul, Selection Day, Cartel
# ----------------------------------------
# Genre: SciFi-
#   No web series with above-average ratings in this genre.
# ----------------------------------------
# Genre: Thriller
#   Web series with above-average ratings: Made in Heaven, Aarya, Candy
# ----------------------------------------
# Genre: Mystery
#   Web series with above-average ratings: Kota Factory, Criminal Justice, Bard of Blood, Tandav, Sunflower, Rocket Boys
# ----------------------------------------
# Genre: Comedy
#   Web series with above-average ratings: Comedy Ray, Mumbai, JL50
# ----------------------------------------

# %% [markdown]
# #Sorry for late submit
